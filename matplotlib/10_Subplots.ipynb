# %% [markdown]
# ## Lets plot salaries of all developers and salaries of python and js developers as two subplots

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('data/10_subplots_data.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

# creating subplots
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

# lets plot salaries of all developers on axis 1 
ax1.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

# now lets plot python and js developers salaries on axis 2
ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')

ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

# can save the figures like this
# fig1.savefig('fig1.png')
# fig2.savefig('fig2.png')
