# %% [markdown]
# ## Lets plot a Time Series Bitcoin stock price data

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.style.use('seaborn')

data = pd.read_csv('data/8_time_series_data.csv')

# converting date values to proper datetime format with help of pandas
data['Date'] = pd.to_datetime(data['Date'])
# lets sort the data based on Date values
data.sort_values('Date', inplace=True)

price_date = data['Date']
price_close = data['Close']

# plotting the dates
plt.plot_date(price_date, price_close, linestyle='solid')

# get current figure and rotate the dates and right align them.
plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()

plt.show()
